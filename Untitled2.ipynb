# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexpotrebitel/-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# проанализировать данные с помощью PairGrid с типом графика на ваш выбор. 2уточнить групировку данных с помощью 2-3 точечных графиков(hue, size,stile) использовать 2-3 гистограммы

# %%
import seaborn as sns

# %%
import pandas as pd
pg=sns.load_dataset('penguins')

# %%
pg.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.PairGrid(pg[['bill_length_mm','bill_depth_mm']])

# %% [markdown]
# проанализировать данные с помощью PairGrid с типом графика на ваш выбор

# %%
calls=['bill_length_mm', 'bill_depth_mm','flipper_length_mm','body_mass_g']
pg_table=sns.PairGrid(pg[calls])
pg_table.map(sns.scatterplot)

# %% [markdown]
# уточнить группировку данных с помощью 2-3 точечных графиков(hue, size, style) использовать 2-3 гимтограммы

# %%
sns.scatterplot(pg,x='flipper_length_mm',y='bill_depth_mm',hue='sex')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(pg,x='flipper_length_mm',y='bill_length_mm', hue='species')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_length_mm'>

# %%
sns.scatterplot(pg,x='flipper_length_mm',y='bill_depth_mm', hue='island')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(pg,x='species',y='island')
# Out:
# <Axes: xlabel='species', ylabel='island'>

# %%
sns.histplot(pg,x='bill_depth_mm',hue='island')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='Count'>

# %%
sns.histplot(pg,x='bill_depth_mm',hue='species')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='Count'>

# %%
sns.histplot(pg,x='bill_depth_mm', hue='sex')
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='Count'>

# %%
pg.loc[pg["bill_length_mm"]>42,"leght"]="high"
pg.loc[(pg["bill_length_mm"]<=42)&(pg["bill_length_mm"]>35),"leght"]="middle"
pg.loc[pg['bill_length_mm']<35, 'leght']='low'

# %%
pg.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex legth   leght
# 0       3750.0    Male   NaN  middle
# 1       3800.0  Female   NaN  middle
# 2       3250.0  Female   NaN  middle
# 3          NaN     NaN   NaN     NaN
# 4       3450.0  Female   NaN  middle

# %%
sns.histplot(pg,x='bill_length_mm',hue='leght')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.histplot(pg,x='flipper_length_mm',hue='leght')
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(pg,x='sex', hue=''
