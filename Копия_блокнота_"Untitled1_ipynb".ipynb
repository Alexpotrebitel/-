# %% [markdown]
# <a href="https://colab.research.google.com/github/Alexpotrebitel/-/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22Untitled1_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 10.1 * используйте точечный график дляотображения зависимости population от household* используйте линейный график для отображения зависимости median_house_value от longnitude. *представить программу по housing_median_age
# *усложнение изобразить гистограмму по median_house_value с оттенком housing_median_age три оттенка на выбор*усложнение сформировать гипотезу о дорогих домах

# %%
import pandas as pd
import seaborn as sb

# %%
dt=pd.read_csv('sample_data/california_housing_test.csv')

# %%
dt.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# используйте точечный график для отображения poulation от houshold

# %%
sb.scatterplot(dt,x='households', y='population')
# Out:
# <Axes: xlabel='households', ylabel='population'>

# %% [markdown]
# используйте линейный график для отображения зависимости median_house_value от lognitude

# %%
sb.relplot(dt,x='longitude',y='median_house_value',kind='line')

# %% [markdown]
# предоставить гистограмму по hosing_median_age

# %%
sb.histplot(dt,x='housing_median_age')
# Out:
# <Axes: xlabel='housing_median_age', ylabel='Count'>

# %% [markdown]
# усложнение. изобразить гистограмму по median_house_value с оттенком housing_median_age

# %%
dt.loc[dt['median_house_value']>30,'Age']='old'
dt.loc[(dt['median_house_value']<=30)& dt['median_house_value']>15,'Age']='median'
dt.loc[dt['median_house_value']<=15,'Age']='Young'
dt.head
# Out:
# <bound method NDFrame.head of       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
# ...

# %%
sb.hisplot(dt)
